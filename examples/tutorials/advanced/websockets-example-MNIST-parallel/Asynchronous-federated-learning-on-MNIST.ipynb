# %% [markdown]
# # Tutorial: Asynchronous federated learning on MNIST
#
# This notebook will go through the steps to run a federated learning via websocket workers in an asynchronous way using [TrainConfig](https://github.com/OpenMined/PySyft/blob/dev/examples/tutorials/advanced/Federated%20Learning%20with%20TrainConfig/Introduction%20to%20TrainConfig.ipynb). We will use federated averaging to join the remotely trained models.
#
# Authors:
# - Silvia - GitHub [@midokura-silvia](https://github.com/midokura-silvia)
# - Marianne Monteiro - Twitter [@hereismari](https://twitter.com/hereismari) - Github [@mari-linhares
# ](https://github.com/mari-linhares)

# %%
# %load_ext autoreload
# %autoreload 2

import inspect

# %% [markdown]
# ## Federated Learning setup
#
# For a Federated Learning setup with TrainConfig we need different participants:
#
# * _Workers_ that own datasets.
#
# * An entity that knows the workers and the dataset name that lives in each worker. We'll call this a _scheduler_.
#
# Each worker is represented by two parts, a proxy local to the scheduler (websocket client worker) and the remote instance that holds the data and performs the computations. The remote part is called a websocket server worker.

# %% [markdown]
# ## Preparation: Start the websocket workers
# So first, we need to create the remote workers. For this, you need to run in a terminal (not possible from the notebook):
#
# ```bash
# python start_websocket_servers.py
# ```
#
# #### What's going on?
#
# The script will instantiate three workers, Alice, Bob and Charlie and prepare their local data.
# Each worker is set up to have a subset of the MNIST training dataset.
# Alice holds all images corresponding to the digits 0-3,
# Bob holds all images corresponding to the digits 4-6 and
# Charlie holds all images corresponding to the digits 7-9.
#
# | Worker      | Digits in local dataset | Number of samples |
# | ----------- | ----------------------- | ----------------- |
# | Alice       | 0-3                     | 24754             |
# | Bob         | 4-6                     | 17181             |
# | Charlie     | 7-9                     | 18065             |

# %%
# uncomment the following to see the code of the function that starts a worker
# import run_websocket_server

# print(inspect.getsource(run_websocket_server.start_websocket_server_worker))

# %% [markdown]
# Before continuing let's first need to import dependencies, setup needed arguments and configure logging.

# %%
# Dependencies
import sys
import asyncio

import syft as sy
from syft.workers import WebsocketClientWorker
from syft.frameworks.torch.federated import utils

import torch
from torchvision import datasets, transforms

import run_websocket_client as rwc
if torch.__version__>= "1.0.2":
    raise ValueError(f"This tutorial currently does not support torch versions >= 1.0.2, you have version {torch.__version__}")
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0815 17:55:03.663894 140351959332608 secure_random.py:26] Falling back to insecure randomness since the required custom op could not be found for the installed version of TensorFlow. Fix this by compiling custom ops. Missing file was '/home/deeplearning/thirdparty_sw/miniconda3/lib/python3.7/site-packages/tf_encrypted-0.5.7rc1-py3.7-linux-x86_64.egg/tf_encrypted/operations/secure_random/secure_random_module_tf_1.14.0.so'
# W0815 17:55:03.692612 140351959332608 deprecation_wrapper.py:119] From /home/deeplearning/thirdparty_sw/miniconda3/lib/python3.7/site-packages/tf_encrypted-0.5.7rc1-py3.7-linux-x86_64.egg/tf_encrypted/session.py:26: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.

# %%
# Hook torch
hook = sy.TorchHook(torch)

# %%
# Arguments
args = rwc.define_and_get_arguments(args=[])
use_cuda = args.cuda and torch.cuda.is_available()
torch.manual_seed(args.seed)
device = torch.device("cuda" if use_cuda else "cpu")
args.save_model = True
print(args)
# Out:
# Namespace(batch_size=32, cuda=False, federate_after_n_batches=10, lr=0.1, save_model=True, seed=1, test_batch_size=128, training_rounds=40, verbose=False)

# %%
# Configure logging
import logging

logger = logging.getLogger("run_websocket_client")

if not len(logger.handlers):
    FORMAT = "%(asctime)s - %(message)s"
    DATE_FMT = "%H:%M:%S"
    formatter = logging.Formatter(FORMAT, DATE_FMT)
    handler = logging.StreamHandler()
    handler.setFormatter(formatter)
    logger.addHandler(handler)
    logger.propagate = False
LOG_LEVEL = logging.DEBUG
logger.setLevel(LOG_LEVEL)

# %% [markdown]
# Now let's instantiate the websocket client workers, our local proxies to the remote workers.
# Note that **this step will fail, if the websocket server workers are not running**.

# %%
kwargs_websocket = {"host": "localhost", "hook": hook, "verbose": args.verbose}
alice = WebsocketClientWorker(id="alice", port=8777, **kwargs_websocket)
bob = WebsocketClientWorker(id="bob", port=8778, **kwargs_websocket)
charlie = WebsocketClientWorker(id="charlie", port=8779, **kwargs_websocket)
testing = WebsocketClientWorker(id="testing", port=8780,  **kwargs_websocket)

worker_instances = [alice, bob, charlie]
print(worker_instances)
# Out:
# [<WebsocketClientWorker id:alice #objects local:0 #objects remote: 2>, <WebsocketClientWorker id:bob #objects local:0 #objects remote: 2>, <WebsocketClientWorker id:charlie #objects local:0 #objects remote: 2>]

# %% [markdown]
# ## Setting up training

# %% [markdown]
# ### Model
# Let's instantiate the machine learning model. It is a small neural network with 2 convolutional and two fully connected layers.
# It uses ReLU activations and max pooling.

# %%
print(inspect.getsource(rwc.Net))
# Out:
# class Net(nn.Module):
#     def __init__(self):
#         super(Net, self).__init__()
#         self.conv1 = nn.Conv2d(1, 20, 5, 1)
#         self.conv2 = nn.Conv2d(20, 50, 5, 1)
#         self.fc1 = nn.Linear(4 * 4 * 50, 500)
#         self.fc2 = nn.Linear(500, 10)
#
#     def forward(self, x):
#         x = F.relu(self.conv1(x))
#         x = F.max_pool2d(x, 2, 2)
#         x = F.relu(self.conv2(x))
#         x = F.max_pool2d(x, 2, 2)
#         x = x.view(-1, 4 * 4 * 50)
#         x = F.relu(self.fc1(x))
#         x = self.fc2(x)
#         return F.log_softmax(x, dim=1)

# %%
model = rwc.Net().to(device)
print(model)
# Out:
# Net(
#   (conv1): Conv2d(1, 20, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(20, 50, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=800, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )

# %% [markdown]
# ### Test Data
#
# The training data lives in each of the devices, but fefore starting the training, let's load the MNIST test data

# %%
test_loader = torch.utils.data.DataLoader(
        datasets.MNIST(
            "./data",
            train=False,
            download=True,
            transform=transforms.Compose(
                [transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))]
            ),
        ),
        batch_size=args.test_batch_size,
        shuffle=False,
        drop_last=False,
    )
(data, target) = test_loader.__iter__().next()

# %% [markdown]
# #### Making the model serializable
#
# In order to send the model to the workers we need the model to be serializable, for this we use [`jit`](https://pytorch.org/docs/stable/jit.html).

# %%
traced_model = torch.jit.trace(model, data)

# %% [markdown]
# ### Let's start the training
#
# Now we are ready to start the federated training. We will perform training over a given number of batches separately on each worker and then calculate the federated average of the resulting model.
#
# Every 10th training round we will evaluate the performance of the models returned by the workers and of the model obtained by federated averaging.
#
# The performance will be given both as the accuracy (ratio of correct predictions) and as the histograms of predicted digits. This is of interest, as each worker only owns a subset of the digits. Therefore, in the beginning each worker will only predict their numbers and only know about the other numbers via the federated averaging process.
#
# The training is done in an asynchronous manner. This means that the scheduler just tell the workers to train and does not block to wait for the result of the training before talking to the next worker.

# %% [markdown]
# The parameters of the training are given in the arguments.
# Each worker will train on a given number of batches, given by the value of federate_after_n_batches.
# The training batch size and learning rate are also configured.

# %%
print("Federate_after_n_batches: " + str(args.federate_after_n_batches))
print("Batch size: " + str(args.batch_size))
print("Initial learning rate: " + str(args.lr))
# Out:
# Federate_after_n_batches: 10
# Batch size: 32
# Initial learning rate: 0.1

# %%
learning_rate = args.lr
import numpy as np
for curr_round in range(1, args.training_rounds + 1):
    global traced_model
    
    logger.info("Starting training round %s/%s", curr_round, args.training_rounds)

    # For each of the workers we ask the model to train with their part of their data
    # in a async fashion and then we gather the results
    results = await asyncio.gather(
        *[
            rwc.fit_model_on_worker(
                worker=worker,
                traced_model=traced_model,
                batch_size=args.batch_size,
                curr_round=curr_round,
                max_nr_batches=args.federate_after_n_batches,
                lr=learning_rate,
            )
            for worker in worker_instances
        ]
    )
    
    models = {}
    loss_values = {}

    """
    # Run evaluation every 10 rounds
    run_evaluation = (curr_round) % 10 == 1 or curr_round == args.training_rounds
    if run_evaluation:
        rwc.evaluate_models_on_test_data(test_loader, results)
         
    # Store models and loss_values for each worker
    for worker_id, worker_model, worker_loss in results:
        if worker_model is not None:
            models[worker_id] = worker_model
            loss_values[worker_id] = worker_loss

    """
    
    test_models = curr_round % 3 == 1 or curr_round == args.training_rounds
    if test_models:
            np.set_printoptions(formatter={"float": "{: .0f}".format})
            for worker_id, worker_model, _ in results:
                rwc.evaluate_model_on_worker(
                    model_identifier=worker_id,
                    worker=testing,
                    dataset_key="mnist_testing",
                    model=worker_model,
                    nr_bins=10,
                    batch_size=128,
                    print_target_hist=False,
                )

    for worker_id, worker_model, worker_loss in results:
        if worker_model is not None:
                models[worker_id] = worker_model
                loss_values[worker_id] = worker_loss

    averaged_model = utils.federated_avg(models)
    
    if test_models:
            rwc.evaluate_model_on_worker(
                model_identifier="Federated model",
                worker=testing,
                dataset_key="mnist_testing",
                model=averaged_model,
                nr_bins=10,
                batch_size=128,
                print_target_hist=True,
            )
    """
    # Average model
    avg_model = utils.federated_avg(models)
    
    
    if run_evaluation:
        rwc.evaluate_model("Federated model", avg_model, "cpu", test_loader)
    """
    # decay learning rate
    learning_rate = max(0.98 * learning_rate, args.lr * 0.01)
    
    # Use averaged model in the next round
    traced_model = averaged_model

# Save model
if args.save_model:
    torch.save(averaged_model.state_dict(), "mnist_cnn.pt")
# Out:
# 18:09:50 - Starting training round 1/40
# 18:09:51 - Training round 1, calling fit on worker: alice
# 18:09:51 - Training round 1, calling fit on worker: bob
# 18:09:51 - Training round 1, calling fit on worker: charlie
# 18:09:52 - Training round: 1, worker: charlie, avg_loss: tensor(1.6699, grad_fn=<MeanBackward1>)
# 18:09:56 - Training round: 1, worker: alice, avg_loss: tensor(0.5896, grad_fn=<MeanBackward1>)
# 18:09:57 - Training round: 1, worker: bob, avg_loss: tensor(0.5090, grad_fn=<MeanBackward1>)
# 18:10:02 - alice: Prediction hist.: [ 1830  1032  5296  1842  0  0  0  0  0  0]
# 18:10:02 - alice: Percentage numbers 0-3: 1.0
# 18:10:02 - alice: Percentage numbers 4-6: 0.0
# 18:10:02 - alice: Percentage numbers 7-9: 0.0
# 18:10:02 - alice: Test set: Average loss: 0.0284, Accuracy: 3633/10000 (36.33)
# 18:10:06 - bob: Prediction hist.: [ 0  0  0  0  4168  1927  3905  0  0  0]
# 18:10:06 - bob: Percentage numbers 0-3: 0.0
# 18:10:06 - bob: Percentage numbers 4-6: 1.0
# 18:10:06 - bob: Percentage numbers 7-9: 0.0
# 18:10:06 - bob: Test set: Average loss: 0.0335, Accuracy: 2503/10000 (25.03)
# 18:10:09 - charlie: Prediction hist.: [ 0  0  0  0  0  0  0  95  7183  2722]
# 18:10:09 - charlie: Percentage numbers 0-3: 0.0
# 18:10:09 - charlie: Percentage numbers 4-6: 0.0
# 18:10:09 - charlie: Percentage numbers 7-9: 1.0
# 18:10:09 - charlie: Test set: Average loss: 0.0213, Accuracy: 1928/10000 (19.28)
# 18:10:13 - Target histogram: [ 980  1135  1032  1010  982  892  958  1028  974  1009]
# 18:10:13 - Federated model: Prediction hist.: [ 942  1343  980  624  805  580  883  58  1758  2027]
# 18:10:13 - Federated model: Percentage numbers 0-3: 0.3889
# 18:10:13 - Federated model: Percentage numbers 4-6: 0.2268
# 18:10:13 - Federated model: Percentage numbers 7-9: 0.3843
# 18:10:13 - Federated model: Test set: Average loss: 0.0131, Accuracy: 6394/10000 (63.94)
# 18:10:13 - Starting training round 2/40
# 18:10:13 - Training round 2, calling fit on worker: alice
# 18:10:13 - Training round 2, calling fit on worker: bob
# 18:10:13 - Training round 2, calling fit on worker: charlie
# 18:10:14 - Training round: 2, worker: bob, avg_loss: tensor(0.1650, grad_fn=<MeanBackward1>)
# 18:10:16 - Training round: 2, worker: charlie, avg_loss: tensor(0.7680, grad_fn=<MeanBackward1>)
# 18:10:17 - Training round: 2, worker: alice, avg_loss: tensor(0.2564, grad_fn=<MeanBackward1>)
# 18:10:19 - Starting training round 3/40
# 18:10:19 - Training round 3, calling fit on worker: alice
# 18:10:19 - Training round 3, calling fit on worker: bob
# 18:10:19 - Training round 3, calling fit on worker: charlie
# 18:10:20 - Training round: 3, worker: charlie, avg_loss: tensor(0.4409, grad_fn=<MeanBackward1>)
# 18:10:21 - Training round: 3, worker: alice, avg_loss: tensor(0.1286, grad_fn=<MeanBackward1>)
# 18:10:23 - Training round: 3, worker: bob, avg_loss: tensor(0.1123, grad_fn=<MeanBackward1>)
# 18:10:24 - Starting training round 4/40
# 18:10:24 - Training round 4, calling fit on worker: alice
# 18:10:24 - Training round 4, calling fit on worker: bob
# 18:10:24 - Training round 4, calling fit on worker: charlie
# 18:10:25 - Training round: 4, worker: charlie, avg_loss: tensor(0.1890, grad_fn=<MeanBackward1>)
# 18:10:26 - Training round: 4, worker: bob, avg_loss: tensor(0.0782, grad_fn=<MeanBackward1>)
# 18:10:28 - Training round: 4, worker: alice, avg_loss: tensor(0.0927, grad_fn=<MeanBackward1>)
# 18:10:32 - alice: Prediction hist.: [ 2316  1899  980  4708  92  0  2  3  0  0]
# 18:10:32 - alice: Percentage numbers 0-3: 0.9903
# 18:10:32 - alice: Percentage numbers 4-6: 0.0094
# 18:10:32 - alice: Percentage numbers 7-9: 0.0003
# 18:10:32 - alice: Test set: Average loss: 0.0180, Accuracy: 3966/10000 (39.66)
# 18:10:35 - bob: Prediction hist.: [ 0  294  1  0  2885  4067  2431  322  0  0]
# 18:10:35 - bob: Percentage numbers 0-3: 0.0295
# 18:10:35 - bob: Percentage numbers 4-6: 0.9383
# 18:10:35 - bob: Percentage numbers 7-9: 0.0322
# 18:10:35 - bob: Test set: Average loss: 0.0269, Accuracy: 3376/10000 (33.76)
# 18:10:38 - charlie: Prediction hist.: [ 2  2  0  0  0  0  0  2676  5131  2189]
# 18:10:38 - charlie: Percentage numbers 0-3: 0.0004
# 18:10:38 - charlie: Percentage numbers 4-6: 0.0
# 18:10:38 - charlie: Percentage numbers 7-9: 0.9996
# 18:10:38 - charlie: Test set: Average loss: 0.0220, Accuracy: 2801/10000 (28.01)
# 18:10:42 - Target histogram: [ 980  1135  1032  1010  982  892  958  1028  974  1009]
# 18:10:42 - Federated model: Prediction hist.: [ 1016  1179  770  991  1694  789  1054  1409  948  150]
# 18:10:42 - Federated model: Percentage numbers 0-3: 0.3956
# 18:10:42 - Federated model: Percentage numbers 4-6: 0.3537
# 18:10:42 - Federated model: Percentage numbers 7-9: 0.2507
# 18:10:42 - Federated model: Test set: Average loss: 0.0053, Accuracy: 8010/10000 (80.10)
# 18:10:42 - Starting training round 5/40
# 18:10:42 - Training round 5, calling fit on worker: alice
# 18:10:43 - Training round 5, calling fit on worker: bob
# 18:10:43 - Training round 5, calling fit on worker: charlie
# 18:10:44 - Training round: 5, worker: charlie, avg_loss: tensor(0.4105, grad_fn=<MeanBackward1>)
# 18:10:45 - Training round: 5, worker: bob, avg_loss: tensor(0.1570, grad_fn=<MeanBackward1>)
# 18:10:47 - Training round: 5, worker: alice, avg_loss: tensor(0.2945, grad_fn=<MeanBackward1>)
# 18:10:48 - Starting training round 6/40
# 18:10:48 - Training round 6, calling fit on worker: alice
# 18:10:48 - Training round 6, calling fit on worker: bob
# 18:10:48 - Training round 6, calling fit on worker: charlie
# 18:10:49 - Training round: 6, worker: bob, avg_loss: tensor(0.1178, grad_fn=<MeanBackward1>)
# 18:10:51 - Training round: 6, worker: alice, avg_loss: tensor(0.0549, grad_fn=<MeanBackward1>)
# 18:10:52 - Training round: 6, worker: charlie, avg_loss: tensor(0.5878, grad_fn=<MeanBackward1>)
# 18:10:54 - Starting training round 7/40
# 18:10:54 - Training round 7, calling fit on worker: alice
# 18:10:54 - Training round 7, calling fit on worker: bob
# 18:10:54 - Training round 7, calling fit on worker: charlie
# 18:10:56 - Training round: 7, worker: bob, avg_loss: tensor(0.0641, grad_fn=<MeanBackward1>)
# 18:10:58 - Training round: 7, worker: alice, avg_loss: tensor(0.1124, grad_fn=<MeanBackward1>)
# 18:10:59 - Training round: 7, worker: charlie, avg_loss: tensor(0.1327, grad_fn=<MeanBackward1>)
# 18:11:05 - alice: Prediction hist.: [ 1639  1867  1927  2722  927  23  155  676  36  28]
# 18:11:05 - alice: Percentage numbers 0-3: 0.8155
# 18:11:05 - alice: Percentage numbers 4-6: 0.1105
# 18:11:05 - alice: Percentage numbers 7-9: 0.074
# 18:11:05 - alice: Test set: Average loss: 0.0108, Accuracy: 5641/10000 (56.41)
# 18:11:09 - bob: Prediction hist.: [ 97  970  278  1  2010  3936  1973  735  0  0]
# 18:11:09 - bob: Percentage numbers 0-3: 0.1346
# 18:11:09 - bob: Percentage numbers 4-6: 0.7919
# 18:11:09 - bob: Percentage numbers 7-9: 0.0735
# 18:11:09 - bob: Test set: Average loss: 0.0164, Accuracy: 4817/10000 (48.17)
# 18:11:13 - charlie: Prediction hist.: [ 210  170  123  0  0  0  199  1633  5234  2431]
# 18:11:13 - charlie: Percentage numbers 0-3: 0.0503
# 18:11:13 - charlie: Percentage numbers 4-6: 0.0199
# 18:11:13 - charlie: Percentage numbers 7-9: 0.9298
# 18:11:13 - charlie: Test set: Average loss: 0.0184, Accuracy: 3523/10000 (35.23)
# 18:11:17 - Target histogram: [ 980  1135  1032  1010  982  892  958  1028  974  1009]
# 18:11:17 - Federated model: Prediction hist.: [ 990  1162  938  914  1065  842  1074  1180  968  867]
# 18:11:17 - Federated model: Percentage numbers 0-3: 0.4004
# 18:11:17 - Federated model: Percentage numbers 4-6: 0.2981
# 18:11:17 - Federated model: Percentage numbers 7-9: 0.3015
# 18:11:17 - Federated model: Test set: Average loss: 0.0035, Accuracy: 8848/10000 (88.48)
# 18:11:17 - Starting training round 8/40
# 18:11:17 - Training round 8, calling fit on worker: alice
# 18:11:17 - Training round 8, calling fit on worker: bob
# 18:11:17 - Training round 8, calling fit on worker: charlie
# 18:11:18 - Training round: 8, worker: bob, avg_loss: tensor(0.1187, grad_fn=<MeanBackward1>)
# 18:11:19 - Training round: 8, worker: alice, avg_loss: tensor(0.1135, grad_fn=<MeanBackward1>)
# 18:11:20 - Training round: 8, worker: charlie, avg_loss: tensor(0.2279, grad_fn=<MeanBackward1>)
# 18:11:22 - Starting training round 9/40
# 18:11:22 - Training round 9, calling fit on worker: alice
# 18:11:22 - Training round 9, calling fit on worker: bob
# 18:11:22 - Training round 9, calling fit on worker: charlie
# 18:11:23 - Training round: 9, worker: bob, avg_loss: tensor(0.0243, grad_fn=<MeanBackward1>)
# 18:11:24 - Training round: 9, worker: alice, avg_loss: tensor(0.1879, grad_fn=<MeanBackward1>)
# 18:11:26 - Training round: 9, worker: charlie, avg_loss: tensor(0.3039, grad_fn=<MeanBackward1>)
# 18:11:27 - Starting training round 10/40
# 18:11:27 - Training round 10, calling fit on worker: alice
# 18:11:27 - Training round 10, calling fit on worker: bob
# 18:11:27 - Training round 10, calling fit on worker: charlie
# 18:11:28 - Training round: 10, worker: charlie, avg_loss: tensor(0.1718, grad_fn=<MeanBackward1>)
# 18:11:29 - Training round: 10, worker: bob, avg_loss: tensor(0.2195, grad_fn=<MeanBackward1>)
# 18:11:31 - Training round: 10, worker: alice, avg_loss: tensor(0.1016, grad_fn=<MeanBackward1>)
# 18:11:35 - alice: Prediction hist.: [ 1891  1243  895  4639  452  60  316  366  101  37]
# 18:11:35 - alice: Percentage numbers 0-3: 0.8668
# 18:11:35 - alice: Percentage numbers 4-6: 0.0828
# 18:11:35 - alice: Percentage numbers 7-9: 0.0504
# 18:11:35 - alice: Test set: Average loss: 0.0135, Accuracy: 5177/10000 (51.77)
# 18:11:38 - bob: Prediction hist.: [ 1  1030  294  0  2277  4518  1143  737  0  0]
# 18:11:38 - bob: Percentage numbers 0-3: 0.1325
# 18:11:38 - bob: Percentage numbers 4-6: 0.7938
# 18:11:38 - bob: Percentage numbers 7-9: 0.0737
# 18:11:38 - bob: Test set: Average loss: 0.0222, Accuracy: 4773/10000 (47.73)
# 18:11:42 - charlie: Prediction hist.: [ 513  419  277  62  0  4  219  1308  5229  1969]
# 18:11:42 - charlie: Percentage numbers 0-3: 0.1271
# 18:11:42 - charlie: Percentage numbers 4-6: 0.0223
# 18:11:42 - charlie: Percentage numbers 7-9: 0.8506
# 18:11:42 - charlie: Test set: Average loss: 0.0158, Accuracy: 4339/10000 (43.39)
# 18:11:45 - Target histogram: [ 980  1135  1032  1010  982  892  958  1028  974  1009]
# 18:11:45 - Federated model: Prediction hist.: [ 981  1143  908  927  1451  1248  1023  1082  868  369]
# 18:11:45 - Federated model: Percentage numbers 0-3: 0.3959
# 18:11:45 - Federated model: Percentage numbers 4-6: 0.3722
# 18:11:45 - Federated model: Percentage numbers 7-9: 0.2319
# 18:11:45 - Federated model: Test set: Average loss: 0.0032, Accuracy: 8572/10000 (85.72)
# 18:11:45 - Starting training round 11/40
# 18:11:45 - Training round 11, calling fit on worker: alice
# 18:11:45 - Training round 11, calling fit on worker: bob
# 18:11:46 - Training round 11, calling fit on worker: charlie
# 18:11:46 - Training round: 11, worker: bob, avg_loss: tensor(0.0164, grad_fn=<MeanBackward1>)
# 18:11:48 - Training round: 11, worker: alice, avg_loss: tensor(0.1304, grad_fn=<MeanBackward1>)
# 18:11:49 - Training round: 11, worker: charlie, avg_loss: tensor(0.3231, grad_fn=<MeanBackward1>)
# 18:11:50 - Starting training round 12/40
# 18:11:51 - Training round 12, calling fit on worker: alice
# 18:11:51 - Training round 12, calling fit on worker: bob
# 18:11:51 - Training round 12, calling fit on worker: charlie
# 18:11:52 - Training round: 12, worker: charlie, avg_loss: tensor(0.0623, grad_fn=<MeanBackward1>)
# 18:11:53 - Training round: 12, worker: alice, avg_loss: tensor(0.0540, grad_fn=<MeanBackward1>)
# 18:11:54 - Training round: 12, worker: bob, avg_loss: tensor(0.0740, grad_fn=<MeanBackward1>)
# 18:11:55 - Starting training round 13/40
# 18:11:56 - Training round 13, calling fit on worker: alice
# 18:11:56 - Training round 13, calling fit on worker: bob
# 18:11:56 - Training round 13, calling fit on worker: charlie
# 18:11:57 - Training round: 13, worker: alice, avg_loss: tensor(0.2307, grad_fn=<MeanBackward1>)
# 18:11:58 - Training round: 13, worker: bob, avg_loss: tensor(0.0108, grad_fn=<MeanBackward1>)
# 18:11:59 - Training round: 13, worker: charlie, avg_loss: tensor(0.3422, grad_fn=<MeanBackward1>)
# 18:12:06 - alice: Prediction hist.: [ 2660  1348  1615  1461  1697  5  141  765  282  26]
# 18:12:06 - alice: Percentage numbers 0-3: 0.7084
# 18:12:06 - alice: Percentage numbers 4-6: 0.1843
# 18:12:06 - alice: Percentage numbers 7-9: 0.1073
# 18:12:06 - alice: Test set: Average loss: 0.0100, Accuracy: 6107/10000 (61.07)
# 18:12:09 - bob: Prediction hist.: [ 284  987  701  104  2530  3086  1673  624  11  0]
# 18:12:09 - bob: Percentage numbers 0-3: 0.2076
# 18:12:09 - bob: Percentage numbers 4-6: 0.7289
# 18:12:09 - bob: Percentage numbers 7-9: 0.0635
# 18:12:09 - bob: Test set: Average loss: 0.0145, Accuracy: 5413/10000 (54.13)
# 18:12:13 - charlie: Prediction hist.: [ 515  75  55  4  0  0  78  1226  5513  2534]
# 18:12:13 - charlie: Percentage numbers 0-3: 0.0649
# 18:12:13 - charlie: Percentage numbers 4-6: 0.0078
# 18:12:13 - charlie: Percentage numbers 7-9: 0.9273
# 18:12:13 - charlie: Test set: Average loss: 0.0235, Accuracy: 3597/10000 (35.97)
# 18:12:17 - Target histogram: [ 980  1135  1032  1010  982  892  958  1028  974  1009]
# 18:12:17 - Federated model: Prediction hist.: [ 1085  1126  935  1000  211  544  938  1020  1301  1840]
# 18:12:17 - Federated model: Percentage numbers 0-3: 0.4146
# 18:12:17 - Federated model: Percentage numbers 4-6: 0.1693
# 18:12:17 - Federated model: Percentage numbers 7-9: 0.4161
# 18:12:17 - Federated model: Test set: Average loss: 0.0033, Accuracy: 8299/10000 (82.99)
# 18:12:17 - Starting training round 14/40
# 18:12:18 - Training round 14, calling fit on worker: alice
# 18:12:18 - Training round 14, calling fit on worker: bob
# 18:12:18 - Training round 14, calling fit on worker: charlie
# 18:12:19 - Training round: 14, worker: charlie, avg_loss: tensor(0.1232, grad_fn=<MeanBackward1>)
# 18:12:21 - Training round: 14, worker: alice, avg_loss: tensor(0.0241, grad_fn=<MeanBackward1>)
# 18:12:23 - Training round: 14, worker: bob, avg_loss: tensor(0.0815, grad_fn=<MeanBackward1>)
# 18:12:25 - Starting training round 15/40
# 18:12:25 - Training round 15, calling fit on worker: alice
# 18:12:25 - Training round 15, calling fit on worker: bob
# 18:12:25 - Training round 15, calling fit on worker: charlie
# 18:12:27 - Training round: 15, worker: charlie, avg_loss: tensor(0.0928, grad_fn=<MeanBackward1>)
# 18:12:28 - Training round: 15, worker: bob, avg_loss: tensor(0.0209, grad_fn=<MeanBackward1>)
# 18:12:30 - Training round: 15, worker: alice, avg_loss: tensor(0.1724, grad_fn=<MeanBackward1>)
# 18:12:31 - Starting training round 16/40
# 18:12:31 - Training round 16, calling fit on worker: alice
# 18:12:31 - Training round 16, calling fit on worker: bob
# 18:12:31 - Training round 16, calling fit on worker: charlie
# 18:12:32 - Training round: 16, worker: bob, avg_loss: tensor(0.0916, grad_fn=<MeanBackward1>)
# 18:12:34 - Training round: 16, worker: charlie, avg_loss: tensor(0.0975, grad_fn=<MeanBackward1>)
# 18:12:35 - Training round: 16, worker: alice, avg_loss: tensor(0.1354, grad_fn=<MeanBackward1>)
# 18:12:40 - alice: Prediction hist.: [ 1695  1279  1919  2301  797  272  383  447  230  677]
# 18:12:40 - alice: Percentage numbers 0-3: 0.7194
# 18:12:40 - alice: Percentage numbers 4-6: 0.1452
# 18:12:40 - alice: Percentage numbers 7-9: 0.1354
# 18:12:40 - alice: Test set: Average loss: 0.0077, Accuracy: 6782/10000 (67.82)
# 18:12:43 - bob: Prediction hist.: [ 448  1075  832  123  2031  3170  1364  935  22  0]
# 18:12:43 - bob: Percentage numbers 0-3: 0.2478
# 18:12:43 - bob: Percentage numbers 4-6: 0.6565
# 18:12:43 - bob: Percentage numbers 7-9: 0.0957
# 18:12:43 - bob: Test set: Average loss: 0.0105, Accuracy: 6121/10000 (61.21)
# 18:12:46 - charlie: Prediction hist.: [ 768  800  436  541  0  131  626  1209  3263  2226]
# 18:12:46 - charlie: Percentage numbers 0-3: 0.2545
# 18:12:46 - charlie: Percentage numbers 4-6: 0.0757
# 18:12:46 - charlie: Percentage numbers 7-9: 0.6698
# 18:12:46 - charlie: Test set: Average loss: 0.0097, Accuracy: 6162/10000 (61.62)
# 18:12:50 - Target histogram: [ 980  1135  1032  1010  982  892  958  1028  974  1009]
# 18:12:50 - Federated model: Prediction hist.: [ 1013  1146  1048  1009  951  970  975  988  898  1002]
# 18:12:50 - Federated model: Percentage numbers 0-3: 0.4216
# 18:12:50 - Federated model: Percentage numbers 4-6: 0.2896
# 18:12:50 - Federated model: Percentage numbers 7-9: 0.2888
# 18:12:50 - Federated model: Test set: Average loss: 0.0019, Accuracy: 9348/10000 (93.48)
# 18:12:50 - Starting training round 17/40
# 18:12:50 - Training round 17, calling fit on worker: alice
# 18:12:51 - Training round 17, calling fit on worker: bob
# 18:12:51 - Training round 17, calling fit on worker: charlie
# 18:12:52 - Training round: 17, worker: bob, avg_loss: tensor(0.0391, grad_fn=<MeanBackward1>)
# 18:12:53 - Training round: 17, worker: alice, avg_loss: tensor(0.0330, grad_fn=<MeanBackward1>)
# 18:12:55 - Training round: 17, worker: charlie, avg_loss: tensor(0.2229, grad_fn=<MeanBackward1>)
# 18:12:56 - Starting training round 18/40
# 18:12:56 - Training round 18, calling fit on worker: alice
# 18:12:56 - Training round 18, calling fit on worker: bob
# 18:12:57 - Training round 18, calling fit on worker: charlie
# 18:12:58 - Training round: 18, worker: alice, avg_loss: tensor(0.2657, grad_fn=<MeanBackward1>)
# 18:12:59 - Training round: 18, worker: charlie, avg_loss: tensor(0.2151, grad_fn=<MeanBackward1>)
# 18:13:00 - Training round: 18, worker: bob, avg_loss: tensor(0.0609, grad_fn=<MeanBackward1>)
# 18:13:01 - Starting training round 19/40
# 18:13:02 - Training round 19, calling fit on worker: alice
# 18:13:02 - Training round 19, calling fit on worker: bob
# 18:13:02 - Training round 19, calling fit on worker: charlie
# 18:13:03 - Training round: 19, worker: charlie, avg_loss: tensor(0.0363, grad_fn=<MeanBackward1>)
# 18:13:05 - Training round: 19, worker: bob, avg_loss: tensor(0.0084, grad_fn=<MeanBackward1>)
# 18:13:06 - Training round: 19, worker: alice, avg_loss: tensor(0.2887, grad_fn=<MeanBackward1>)
# 18:13:11 - alice: Prediction hist.: [ 1658  1227  2461  1353  900  428  365  610  250  748]
# 18:13:11 - alice: Percentage numbers 0-3: 0.6699
# 18:13:11 - alice: Percentage numbers 4-6: 0.1693
# 18:13:11 - alice: Percentage numbers 7-9: 0.1608
# 18:13:11 - alice: Test set: Average loss: 0.0069, Accuracy: 7224/10000 (72.24)
# 18:13:15 - bob: Prediction hist.: [ 494  1065  799  8  2087  2787  1398  946  416  0]
# 18:13:15 - bob: Percentage numbers 0-3: 0.2366
# 18:13:15 - bob: Percentage numbers 4-6: 0.6272
# 18:13:15 - bob: Percentage numbers 7-9: 0.1362
# 18:13:15 - bob: Test set: Average loss: 0.0106, Accuracy: 6409/10000 (64.09)
# 18:13:18 - charlie: Prediction hist.: [ 879  872  414  460  10  148  743  1311  2864  2299]
# 18:13:18 - charlie: Percentage numbers 0-3: 0.2625
# 18:13:18 - charlie: Percentage numbers 4-6: 0.0901
# 18:13:18 - charlie: Percentage numbers 7-9: 0.6474
# 18:13:18 - charlie: Test set: Average loss: 0.0081, Accuracy: 6408/10000 (64.08)
# 18:13:22 - Target histogram: [ 980  1135  1032  1010  982  892  958  1028  974  1009]
# 18:13:22 - Federated model: Prediction hist.: [ 1022  1136  1071  865  1027  997  965  1009  955  953]
# 18:13:22 - Federated model: Percentage numbers 0-3: 0.4094
# 18:13:22 - Federated model: Percentage numbers 4-6: 0.2989
# 18:13:22 - Federated model: Percentage numbers 7-9: 0.2917
# 18:13:22 - Federated model: Test set: Average loss: 0.0018, Accuracy: 9371/10000 (93.71)
# 18:13:22 - Starting training round 20/40
# 18:13:22 - Training round 20, calling fit on worker: alice
# 18:13:22 - Training round 20, calling fit on worker: bob
# 18:13:22 - Training round 20, calling fit on worker: charlie
# 18:13:24 - Training round: 20, worker: bob, avg_loss: tensor(0.0696, grad_fn=<MeanBackward1>)
# 18:13:25 - Training round: 20, worker: charlie, avg_loss: tensor(0.0134, grad_fn=<MeanBackward1>)
# 18:13:27 - Training round: 20, worker: alice, avg_loss: tensor(0.1613, grad_fn=<MeanBackward1>)
# 18:13:29 - Starting training round 21/40
# 18:13:29 - Training round 21, calling fit on worker: alice
# 18:13:30 - Training round 21, calling fit on worker: bob
# 18:13:30 - Training round 21, calling fit on worker: charlie
# 18:13:32 - Training round: 21, worker: bob, avg_loss: tensor(0.0207, grad_fn=<MeanBackward1>)
# 18:13:34 - Training round: 21, worker: charlie, avg_loss: tensor(0.1710, grad_fn=<MeanBackward1>)
# 18:13:35 - Training round: 21, worker: alice, avg_loss: tensor(0.0430, grad_fn=<MeanBackward1>)
# 18:13:37 - Starting training round 22/40
# 18:13:37 - Training round 22, calling fit on worker: alice
# 18:13:37 - Training round 22, calling fit on worker: bob
# 18:13:37 - Training round 22, calling fit on worker: charlie
# 18:13:38 - Training round: 22, worker: bob, avg_loss: tensor(0.0494, grad_fn=<MeanBackward1>)
# 18:13:40 - Training round: 22, worker: charlie, avg_loss: tensor(0.1643, grad_fn=<MeanBackward1>)
# 18:13:41 - Training round: 22, worker: alice, avg_loss: tensor(0.0168, grad_fn=<MeanBackward1>)
# 18:13:46 - alice: Prediction hist.: [ 1293  1334  1330  1429  1030  619  737  899  507  822]
# 18:13:46 - alice: Percentage numbers 0-3: 0.5386
# 18:13:46 - alice: Percentage numbers 4-6: 0.2386
# 18:13:46 - alice: Percentage numbers 7-9: 0.2228
# 18:13:46 - alice: Test set: Average loss: 0.0034, Accuracy: 8538/10000 (85.38)
# 18:13:50 - bob: Prediction hist.: [ 315  998  872  160  1482  4041  1109  950  65  8]
# 18:13:50 - bob: Percentage numbers 0-3: 0.2345
# 18:13:50 - bob: Percentage numbers 4-6: 0.6632
# 18:13:50 - bob: Percentage numbers 7-9: 0.1023
# 18:13:50 - bob: Test set: Average loss: 0.0097, Accuracy: 6031/10000 (60.31)
# 18:13:53 - charlie: Prediction hist.: [ 525  256  470  315  0  17  565  1398  4655  1799]
# 18:13:53 - charlie: Percentage numbers 0-3: 0.1566
# 18:13:53 - charlie: Percentage numbers 4-6: 0.0582
# 18:13:53 - charlie: Percentage numbers 7-9: 0.7852
# 18:13:53 - charlie: Test set: Average loss: 0.0128, Accuracy: 4958/10000 (49.58)
# 18:13:57 - Target histogram: [ 980  1135  1032  1010  982  892  958  1028  974  1009]
# 18:13:57 - Federated model: Prediction hist.: [ 969  1112  1015  956  913  1013  943  1080  1008  991]
# 18:13:57 - Federated model: Percentage numbers 0-3: 0.4052
# 18:13:57 - Federated model: Percentage numbers 4-6: 0.2869
# 18:13:57 - Federated model: Percentage numbers 7-9: 0.3079
# 18:13:57 - Federated model: Test set: Average loss: 0.0016, Accuracy: 9408/10000 (94.08)
# 18:13:57 - Starting training round 23/40
# 18:13:57 - Training round 23, calling fit on worker: alice
# 18:13:58 - Training round 23, calling fit on worker: bob
# 18:13:58 - Training round 23, calling fit on worker: charlie
# 18:13:59 - Training round: 23, worker: alice, avg_loss: tensor(0.0345, grad_fn=<MeanBackward1>)
# 18:14:00 - Training round: 23, worker: bob, avg_loss: tensor(0.0043, grad_fn=<MeanBackward1>)
# 18:14:01 - Training round: 23, worker: charlie, avg_loss: tensor(0.0619, grad_fn=<MeanBackward1>)
# 18:14:02 - Starting training round 24/40
# 18:14:03 - Training round 24, calling fit on worker: alice
# 18:14:03 - Training round 24, calling fit on worker: bob
# 18:14:03 - Training round 24, calling fit on worker: charlie
# 18:14:04 - Training round: 24, worker: bob, avg_loss: tensor(0.4458, grad_fn=<MeanBackward1>)
# 18:14:05 - Training round: 24, worker: alice, avg_loss: tensor(0.0149, grad_fn=<MeanBackward1>)
# 18:14:06 - Training round: 24, worker: charlie, avg_loss: tensor(0.2138, grad_fn=<MeanBackward1>)
# 18:14:07 - Starting training round 25/40
# 18:14:08 - Training round 25, calling fit on worker: alice
# 18:14:08 - Training round 25, calling fit on worker: bob
# 18:14:08 - Training round 25, calling fit on worker: charlie
# 18:14:09 - Training round: 25, worker: charlie, avg_loss: tensor(0.1281, grad_fn=<MeanBackward1>)
# 18:14:10 - Training round: 25, worker: bob, avg_loss: tensor(0.0747, grad_fn=<MeanBackward1>)
# 18:14:11 - Training round: 25, worker: alice, avg_loss: tensor(0.2557, grad_fn=<MeanBackward1>)
# 18:14:15 - alice: Prediction hist.: [ 1257  1386  1014  2134  1005  402  839  682  448  833]
# 18:14:15 - alice: Percentage numbers 0-3: 0.5791
# 18:14:15 - alice: Percentage numbers 4-6: 0.2246
# 18:14:15 - alice: Percentage numbers 7-9: 0.1963
# 18:14:15 - alice: Test set: Average loss: 0.0045, Accuracy: 8103/10000 (81.03)
# 18:14:18 - bob: Prediction hist.: [ 693  988  962  602  2135  1373  1738  937  568  4]
# 18:14:18 - bob: Percentage numbers 0-3: 0.3245
# 18:14:18 - bob: Percentage numbers 4-6: 0.5246
# 18:14:18 - bob: Percentage numbers 7-9: 0.1509
# 18:14:18 - bob: Test set: Average loss: 0.0064, Accuracy: 7388/10000 (73.88)
# 18:14:23 - charlie: Prediction hist.: [ 627  490  441  255  5  163  646  1064  4177  2132]
# 18:14:23 - charlie: Percentage numbers 0-3: 0.1813
# 18:14:23 - charlie: Percentage numbers 4-6: 0.0814
# 18:14:23 - charlie: Percentage numbers 7-9: 0.7373
# 18:14:23 - charlie: Test set: Average loss: 0.0108, Accuracy: 5499/10000 (54.99)
# 18:14:28 - Target histogram: [ 980  1135  1032  1010  982  892  958  1028  974  1009]
# 18:14:28 - Federated model: Prediction hist.: [ 1001  1134  999  990  991  881  1012  985  1020  987]
# 18:14:28 - Federated model: Percentage numbers 0-3: 0.4124
# 18:14:28 - Federated model: Percentage numbers 4-6: 0.2884
# 18:14:28 - Federated model: Percentage numbers 7-9: 0.2992
# 18:14:28 - Federated model: Test set: Average loss: 0.0014, Accuracy: 9504/10000 (95.04)
# 18:14:28 - Starting training round 26/40
# 18:14:28 - Training round 26, calling fit on worker: alice
# 18:14:28 - Training round 26, calling fit on worker: bob
# 18:14:28 - Training round 26, calling fit on worker: charlie
# 18:14:29 - Training round: 26, worker: bob, avg_loss: tensor(0.0055, grad_fn=<MeanBackward1>)
# 18:14:31 - Training round: 26, worker: charlie, avg_loss: tensor(0.1531, grad_fn=<MeanBackward1>)
# 18:14:32 - Training round: 26, worker: alice, avg_loss: tensor(0.1337, grad_fn=<MeanBackward1>)
# 18:14:33 - Starting training round 27/40
# 18:14:33 - Training round 27, calling fit on worker: alice
# 18:14:33 - Training round 27, calling fit on worker: bob
# 18:14:33 - Training round 27, calling fit on worker: charlie
# 18:14:34 - Training round: 27, worker: charlie, avg_loss: tensor(0.0533, grad_fn=<MeanBackward1>)
# 18:14:36 - Training round: 27, worker: bob, avg_loss: tensor(0.0104, grad_fn=<MeanBackward1>)
# 18:14:38 - Training round: 27, worker: alice, avg_loss: tensor(0.0203, grad_fn=<MeanBackward1>)
# 18:14:40 - Starting training round 28/40
# 18:14:40 - Training round 28, calling fit on worker: alice
# 18:14:40 - Training round 28, calling fit on worker: bob
# 18:14:41 - Training round 28, calling fit on worker: charlie
# 18:14:42 - Training round: 28, worker: bob, avg_loss: tensor(0.0122, grad_fn=<MeanBackward1>)
# 18:14:44 - Training round: 28, worker: alice, avg_loss: tensor(0.0363, grad_fn=<MeanBackward1>)
# 18:14:45 - Training round: 28, worker: charlie, avg_loss: tensor(0.0365, grad_fn=<MeanBackward1>)
# 18:14:49 - alice: Prediction hist.: [ 1372  1236  1114  2119  924  489  686  735  421  904]
# 18:14:49 - alice: Percentage numbers 0-3: 0.5841
# 18:14:49 - alice: Percentage numbers 4-6: 0.2099
# 18:14:49 - alice: Percentage numbers 7-9: 0.206
# 18:14:49 - alice: Test set: Average loss: 0.0043, Accuracy: 8154/10000 (81.54)
# 18:14:53 - bob: Prediction hist.: [ 718  1039  1000  416  1757  2130  1296  948  624  72]
# 18:14:53 - bob: Percentage numbers 0-3: 0.3173
# 18:14:53 - bob: Percentage numbers 4-6: 0.5183
# 18:14:53 - bob: Percentage numbers 7-9: 0.1644
# 18:14:53 - bob: Test set: Average loss: 0.0054, Accuracy: 7491/10000 (74.91)
# 18:14:56 - charlie: Prediction hist.: [ 802  697  362  451  1  262  764  1680  2878  2103]
# 18:14:56 - charlie: Percentage numbers 0-3: 0.2312
# 18:14:56 - charlie: Percentage numbers 4-6: 0.1027
# 18:14:56 - charlie: Percentage numbers 7-9: 0.6661
# 18:14:56 - charlie: Test set: Average loss: 0.0100, Accuracy: 6252/10000 (62.52)
# 18:14:59 - Target histogram: [ 980  1135  1032  1010  982  892  958  1028  974  1009]
# 18:14:59 - Federated model: Prediction hist.: [ 1004  1128  975  996  904  928  958  1038  1006  1063]
# 18:14:59 - Federated model: Percentage numbers 0-3: 0.4103
# 18:14:59 - Federated model: Percentage numbers 4-6: 0.279
# 18:14:59 - Federated model: Percentage numbers 7-9: 0.3107
# 18:14:59 - Federated model: Test set: Average loss: 0.0013, Accuracy: 9531/10000 (95.31)
# 18:14:59 - Starting training round 29/40
# 18:14:59 - Training round 29, calling fit on worker: alice
# 18:15:00 - Training round 29, calling fit on worker: bob
# 18:15:00 - Training round 29, calling fit on worker: charlie
# 18:15:01 - Training round: 29, worker: alice, avg_loss: tensor(0.0368, grad_fn=<MeanBackward1>)
# 18:15:02 - Training round: 29, worker: bob, avg_loss: tensor(0.0258, grad_fn=<MeanBackward1>)
# 18:15:03 - Training round: 29, worker: charlie, avg_loss: tensor(0.0537, grad_fn=<MeanBackward1>)
# 18:15:05 - Starting training round 30/40
# 18:15:05 - Training round 30, calling fit on worker: alice
# 18:15:05 - Training round 30, calling fit on worker: bob
# 18:15:05 - Training round 30, calling fit on worker: charlie
# 18:15:06 - Training round: 30, worker: alice, avg_loss: tensor(0.0122, grad_fn=<MeanBackward1>)
# 18:15:07 - Training round: 30, worker: charlie, avg_loss: tensor(0.1184, grad_fn=<MeanBackward1>)
# 18:15:09 - Training round: 30, worker: bob, avg_loss: tensor(0.0034, grad_fn=<MeanBackward1>)
# 18:15:10 - Starting training round 31/40
# 18:15:10 - Training round 31, calling fit on worker: alice
# 18:15:11 - Training round 31, calling fit on worker: bob
# 18:15:11 - Training round 31, calling fit on worker: charlie
# 18:15:12 - Training round: 31, worker: charlie, avg_loss: tensor(0.0673, grad_fn=<MeanBackward1>)
# 18:15:13 - Training round: 31, worker: alice, avg_loss: tensor(0.0114, grad_fn=<MeanBackward1>)
# 18:15:14 - Training round: 31, worker: bob, avg_loss: tensor(0.0033, grad_fn=<MeanBackward1>)
# 18:15:19 - alice: Prediction hist.: [ 1166  1322  1689  2383  766  187  719  710  225  833]
# 18:15:19 - alice: Percentage numbers 0-3: 0.656
# 18:15:19 - alice: Percentage numbers 4-6: 0.1672
# 18:15:19 - alice: Percentage numbers 7-9: 0.1768
# 18:15:19 - alice: Test set: Average loss: 0.0064, Accuracy: 7478/10000 (74.78)
# 18:15:22 - bob: Prediction hist.: [ 859  1102  962  692  1929  1481  1187  981  678  129]
# 18:15:22 - bob: Percentage numbers 0-3: 0.3615
# 18:15:22 - bob: Percentage numbers 4-6: 0.4597
# 18:15:22 - bob: Percentage numbers 7-9: 0.1788
# 18:15:22 - bob: Test set: Average loss: 0.0042, Accuracy: 8074/10000 (80.74)
# 18:15:25 - charlie: Prediction hist.: [ 853  1029  709  667  20  415  875  1257  1352  2823]
# 18:15:25 - charlie: Percentage numbers 0-3: 0.3258
# 18:15:25 - charlie: Percentage numbers 4-6: 0.131
# 18:15:25 - charlie: Percentage numbers 7-9: 0.5432
# 18:15:25 - charlie: Test set: Average loss: 0.0064, Accuracy: 7411/10000 (74.11)
# 18:15:28 - Target histogram: [ 980  1135  1032  1010  982  892  958  1028  974  1009]
# 18:15:28 - Federated model: Prediction hist.: [ 1005  1150  1038  1079  937  850  959  1020  876  1086]
# 18:15:28 - Federated model: Percentage numbers 0-3: 0.4272
# 18:15:28 - Federated model: Percentage numbers 4-6: 0.2746
# 18:15:28 - Federated model: Percentage numbers 7-9: 0.2982
# 18:15:28 - Federated model: Test set: Average loss: 0.0012, Accuracy: 9533/10000 (95.33)
# 18:15:28 - Starting training round 32/40
# 18:15:28 - Training round 32, calling fit on worker: alice
# 18:15:28 - Training round 32, calling fit on worker: bob
# 18:15:28 - Training round 32, calling fit on worker: charlie
# 18:15:29 - Training round: 32, worker: bob, avg_loss: tensor(0.0118, grad_fn=<MeanBackward1>)
# 18:15:31 - Training round: 32, worker: alice, avg_loss: tensor(0.0110, grad_fn=<MeanBackward1>)
# 18:15:32 - Training round: 32, worker: charlie, avg_loss: tensor(0.0095, grad_fn=<MeanBackward1>)
# 18:15:34 - Starting training round 33/40
# 18:15:34 - Training round 33, calling fit on worker: alice
# 18:15:34 - Training round 33, calling fit on worker: bob
# 18:15:34 - Training round 33, calling fit on worker: charlie
# 18:15:35 - Training round: 33, worker: alice, avg_loss: tensor(0.0101, grad_fn=<MeanBackward1>)
# 18:15:36 - Training round: 33, worker: bob, avg_loss: tensor(0.1368, grad_fn=<MeanBackward1>)
# 18:15:37 - Training round: 33, worker: charlie, avg_loss: tensor(0.0506, grad_fn=<MeanBackward1>)
# 18:15:39 - Starting training round 34/40
# 18:15:39 - Training round 34, calling fit on worker: alice
# 18:15:39 - Training round 34, calling fit on worker: bob
# 18:15:39 - Training round 34, calling fit on worker: charlie
# 18:15:40 - Training round: 34, worker: bob, avg_loss: tensor(0.0267, grad_fn=<MeanBackward1>)
# 18:15:42 - Training round: 34, worker: charlie, avg_loss: tensor(0.1568, grad_fn=<MeanBackward1>)
# 18:15:43 - Training round: 34, worker: alice, avg_loss: tensor(0.0016, grad_fn=<MeanBackward1>)
# 18:15:47 - alice: Prediction hist.: [ 1165  1190  1178  1570  914  598  821  845  753  966]
# 18:15:47 - alice: Percentage numbers 0-3: 0.5103
# 18:15:47 - alice: Percentage numbers 4-6: 0.2333
# 18:15:47 - alice: Percentage numbers 7-9: 0.2564
# 18:15:47 - alice: Test set: Average loss: 0.0026, Accuracy: 8888/10000 (88.88)
# 18:15:51 - bob: Prediction hist.: [ 798  1054  975  369  1997  1898  1394  932  531  52]
# 18:15:51 - bob: Percentage numbers 0-3: 0.3196
# 18:15:51 - bob: Percentage numbers 4-6: 0.5289
# 18:15:51 - bob: Percentage numbers 7-9: 0.1515
# 18:15:51 - bob: Test set: Average loss: 0.0061, Accuracy: 7410/10000 (74.10)
# 18:15:54 - charlie: Prediction hist.: [ 595  970  729  762  348  264  722  1273  2701  1636]
# 18:15:54 - charlie: Percentage numbers 0-3: 0.3056
# 18:15:54 - charlie: Percentage numbers 4-6: 0.1334
# 18:15:54 - charlie: Percentage numbers 7-9: 0.561
# 18:15:54 - charlie: Test set: Average loss: 0.0055, Accuracy: 7268/10000 (72.68)
# 18:15:57 - Target histogram: [ 980  1135  1032  1010  982  892  958  1028  974  1009]
# 18:15:57 - Federated model: Prediction hist.: [ 994  1123  1024  977  1006  935  957  1024  1000  960]
# 18:15:57 - Federated model: Percentage numbers 0-3: 0.4118
# 18:15:57 - Federated model: Percentage numbers 4-6: 0.2898
# 18:15:57 - Federated model: Percentage numbers 7-9: 0.2984
# 18:15:57 - Federated model: Test set: Average loss: 0.0011, Accuracy: 9595/10000 (95.95)
# 18:15:57 - Starting training round 35/40
# 18:15:57 - Training round 35, calling fit on worker: alice
# 18:15:57 - Training round 35, calling fit on worker: bob
# 18:15:58 - Training round 35, calling fit on worker: charlie
# 18:15:59 - Training round: 35, worker: bob, avg_loss: tensor(0.0165, grad_fn=<MeanBackward1>)
# 18:16:00 - Training round: 35, worker: charlie, avg_loss: tensor(0.0361, grad_fn=<MeanBackward1>)
# 18:16:01 - Training round: 35, worker: alice, avg_loss: tensor(0.0071, grad_fn=<MeanBackward1>)
# 18:16:03 - Starting training round 36/40
# 18:16:03 - Training round 36, calling fit on worker: alice
# 18:16:03 - Training round 36, calling fit on worker: bob
# 18:16:03 - Training round 36, calling fit on worker: charlie
# 18:16:04 - Training round: 36, worker: bob, avg_loss: tensor(0.0085, grad_fn=<MeanBackward1>)
# 18:16:05 - Training round: 36, worker: charlie, avg_loss: tensor(0.0304, grad_fn=<MeanBackward1>)
# 18:16:07 - Training round: 36, worker: alice, avg_loss: tensor(0.0579, grad_fn=<MeanBackward1>)
# 18:16:08 - Starting training round 37/40
# 18:16:08 - Training round 37, calling fit on worker: alice
# 18:16:08 - Training round 37, calling fit on worker: bob
# 18:16:08 - Training round 37, calling fit on worker: charlie
# 18:16:09 - Training round: 37, worker: bob, avg_loss: tensor(0.0131, grad_fn=<MeanBackward1>)
# 18:16:10 - Training round: 37, worker: alice, avg_loss: tensor(0.0659, grad_fn=<MeanBackward1>)
# 18:16:12 - Training round: 37, worker: charlie, avg_loss: tensor(0.0641, grad_fn=<MeanBackward1>)
# 18:16:16 - alice: Prediction hist.: [ 1195  1280  1691  2043  894  449  778  633  345  692]
# 18:16:16 - alice: Percentage numbers 0-3: 0.6209
# 18:16:16 - alice: Percentage numbers 4-6: 0.2121
# 18:16:16 - alice: Percentage numbers 7-9: 0.167
# 18:16:16 - alice: Test set: Average loss: 0.0052, Accuracy: 7853/10000 (78.53)
# 18:16:19 - bob: Prediction hist.: [ 920  1112  980  738  1778  1425  1112  1014  665  256]
# 18:16:19 - bob: Percentage numbers 0-3: 0.375
# 18:16:19 - bob: Percentage numbers 4-6: 0.4315
# 18:16:19 - bob: Percentage numbers 7-9: 0.1935
# 18:16:19 - bob: Test set: Average loss: 0.0034, Accuracy: 8351/10000 (83.51)
# 18:16:23 - charlie: Prediction hist.: [ 846  932  674  602  109  484  843  1221  2181  2108]
# 18:16:23 - charlie: Percentage numbers 0-3: 0.3054
# 18:16:23 - charlie: Percentage numbers 4-6: 0.1436
# 18:16:23 - charlie: Percentage numbers 7-9: 0.551
# 18:16:23 - charlie: Test set: Average loss: 0.0055, Accuracy: 7383/10000 (73.83)
# 18:16:26 - Target histogram: [ 980  1135  1032  1010  982  892  958  1028  974  1009]
# 18:16:26 - Federated model: Prediction hist.: [ 1010  1136  1045  1002  970  909  958  1012  951  1007]
# 18:16:26 - Federated model: Percentage numbers 0-3: 0.4193
# 18:16:26 - Federated model: Percentage numbers 4-6: 0.2837
# 18:16:26 - Federated model: Percentage numbers 7-9: 0.297
# 18:16:26 - Federated model: Test set: Average loss: 0.0010, Accuracy: 9611/10000 (96.11)
# 18:16:26 - Starting training round 38/40
# 18:16:26 - Training round 38, calling fit on worker: alice
# 18:16:26 - Training round 38, calling fit on worker: bob
# 18:16:26 - Training round 38, calling fit on worker: charlie
# 18:16:27 - Training round: 38, worker: bob, avg_loss: tensor(0.0479, grad_fn=<MeanBackward1>)
# 18:16:28 - Training round: 38, worker: alice, avg_loss: tensor(0.0052, grad_fn=<MeanBackward1>)
# 18:16:29 - Training round: 38, worker: charlie, avg_loss: tensor(0.1753, grad_fn=<MeanBackward1>)
# 18:16:31 - Starting training round 39/40
# 18:16:31 - Training round 39, calling fit on worker: alice
# 18:16:31 - Training round 39, calling fit on worker: bob
# 18:16:31 - Training round 39, calling fit on worker: charlie
# 18:16:32 - Training round: 39, worker: bob, avg_loss: tensor(0.1436, grad_fn=<MeanBackward1>)
# 18:16:33 - Training round: 39, worker: alice, avg_loss: tensor(0.0039, grad_fn=<MeanBackward1>)
# 18:16:34 - Training round: 39, worker: charlie, avg_loss: tensor(0.0842, grad_fn=<MeanBackward1>)
# 18:16:36 - Starting training round 40/40
# 18:16:36 - Training round 40, calling fit on worker: alice
# 18:16:36 - Training round 40, calling fit on worker: bob
# 18:16:36 - Training round 40, calling fit on worker: charlie
# 18:16:37 - Training round: 40, worker: alice, avg_loss: tensor(0.0065, grad_fn=<MeanBackward1>)
# 18:16:38 - Training round: 40, worker: charlie, avg_loss: tensor(0.0129, grad_fn=<MeanBackward1>)
# 18:16:40 - Training round: 40, worker: bob, avg_loss: tensor(0.0144, grad_fn=<MeanBackward1>)
# 18:16:44 - alice: Prediction hist.: [ 1115  1190  1297  2003  912  462  846  793  525  857]
# 18:16:44 - alice: Percentage numbers 0-3: 0.5605
# 18:16:44 - alice: Percentage numbers 4-6: 0.222
# 18:16:44 - alice: Percentage numbers 7-9: 0.2175
# 18:16:44 - alice: Test set: Average loss: 0.0037, Accuracy: 8437/10000 (84.37)
# 18:16:47 - bob: Prediction hist.: [ 865  1111  1001  400  1698  1864  1092  976  751  242]
# 18:16:47 - bob: Percentage numbers 0-3: 0.3377
# 18:16:47 - bob: Percentage numbers 4-6: 0.4654
# 18:16:47 - bob: Percentage numbers 7-9: 0.1969
# 18:16:47 - bob: Test set: Average loss: 0.0041, Accuracy: 8023/10000 (80.23)
# 18:16:50 - charlie: Prediction hist.: [ 899  825  631  564  345  364  828  1146  2621  1777]
# 18:16:50 - charlie: Percentage numbers 0-3: 0.2919
# 18:16:50 - charlie: Percentage numbers 4-6: 0.1537
# 18:16:50 - charlie: Percentage numbers 7-9: 0.5544
# 18:16:50 - charlie: Test set: Average loss: 0.0058, Accuracy: 7351/10000 (73.51)
# 18:16:53 - Target histogram: [ 980  1135  1032  1010  982  892  958  1028  974  1009]
# 18:16:53 - Federated model: Prediction hist.: [ 1003  1126  1029  980  969  924  953  1013  1003  1000]
# 18:16:53 - Federated model: Percentage numbers 0-3: 0.4138
# 18:16:53 - Federated model: Percentage numbers 4-6: 0.2846
# 18:16:53 - Federated model: Percentage numbers 7-9: 0.3016
# 18:16:53 - Federated model: Test set: Average loss: 0.0010, Accuracy: 9625/10000 (96.25)

# %% [markdown]
# After 40 rounds of training we achieve an accuracy > 95% on the entire testing dataset.
# This is impressing, given that no worker has access to more than 4 digits!!

# %% [markdown]
# # Congratulations!!! - Time to Join the Community!
#
# Congratulations on completing this notebook tutorial! If you enjoyed this and would like to join the movement toward privacy preserving, decentralized ownership of AI and the AI supply chain (data), you can do so in the following ways!
#
# ### Star PySyft on GitHub
#
# The easiest way to help our community is just by starring the GitHub repos! This helps raise awareness of the cool tools we're building.
#
# - [Star PySyft](https://github.com/OpenMined/PySyft)
#
# ### Join our Slack!
#
# The best way to keep up to date on the latest advancements is to join our community! You can do so by filling out the form at [http://slack.openmined.org](http://slack.openmined.org)
#
# ### Join a Code Project!
#
# The best way to contribute to our community is to become a code contributor! At any time you can go to PySyft GitHub Issues page and filter for "Projects". This will show you all the top level Tickets giving an overview of what projects you can join! If you don't want to join a project, but you would like to do a bit of coding, you can also look for more "one off" mini-projects by searching for GitHub issues marked "good first issue".
#
# - [PySyft Projects](https://github.com/OpenMined/PySyft/issues?q=is%3Aopen+is%3Aissue+label%3AProject)
# - [Good First Issue Tickets](https://github.com/OpenMined/PySyft/issues?q=is%3Aopen+is%3Aissue+label%3A%22good+first+issue%22)
#
# ### Donate
#
# If you don't have time to contribute to our codebase, but would still like to lend support, you can also become a Backer on our Open Collective. All donations go toward our web hosting and other community expenses such as hackathons and meetups!
#
# [OpenMined's Open Collective Page](https://opencollective.com/openmined)
